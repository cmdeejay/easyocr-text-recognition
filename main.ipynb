# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH = 'nokia.jpg'

reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
img = cv2.imread(IMAGE_PATH)

for detection in result:
    topleft = tuple(int(val) for val in detection[0][0])
    bottomright = tuple(int(val) for val in detection[0][2])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, topleft, bottomright, (0,255,0), 1)
    img = cv2.putText(img, text, topleft, font, .3, (255,0,0))

plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()
